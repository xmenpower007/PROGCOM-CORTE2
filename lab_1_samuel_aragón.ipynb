# %% [markdown]
# #Laboratorio 1
# ##Ecuaciones empíricas
# ###Resumen:
# >Luego de la breve explicación del profesor, se procedió a realizar una práctica de
# laboratorio que consistió en realizar distintas medidas a varios anillos hechos del
# mismo material, pero con variación es sus tamaños, por lo que mediante equipos del
# laboratorio como un metro o calibre para poder medir diámetros, una balanza digital
# para las masas y un sensor mediante una computadora para medir los periodos de
# oscilación. Esta última medida la utilizamos para encontrar el error experimental, y
# poder determinar que tan buena era la precisión de nuestro laboratorio.
#
# ###Introducción:
# >En este laboratorio se determinarán ciertas características de un set de anillos, en
# total 6 anillos, oscilantes. Donde se buscará tomar medidas de cada anillo,
# internamente y externamente; además, se determinará la masa individualmente y
# por último, el periodo de oscilación.
# Se buscan estas tres características generales para finalmente determinar cómo
# varía en cada anillo el periodo de oscilación dependiente de su dimensión (diámetro)
# y su masa (peso). Previamente podemos brindar una hipótesis en base a la fórmula
# presentada ‘Fórmula del periodo’.
#
# * 𝑻 = 𝟐𝝅√𝑫/𝒈 (1)
#
# >𝑫: Se refiere a la longitud, en este caso el diámetro de cada anillo
#
# >𝒈: Hace referencia a la aceleración de la gravedad.
# Teniendo en cuenta la ecuación (1) se puede brindar la hipótesis que grababa:
# mientras más diámetro o longitud tenga el anillo, su periodo tendería a aumentar.
# Por lo tanto, entre más grande su diámetro más lento sería el periodo de oscilación.
#
# ###DESARROLLO EXPERIMENTAL

# %% [markdown]
# ![lab 1 img1.png](data:image/png;base64,...)

# %% [markdown]
# ###DIÁMETRO INTERIOR

# %% [markdown]
# ![lab 1 img2.png](data:image/png;base64,...)

# %% [markdown]
# ###MASA

# %% [markdown]
# ![lab 1 img3.png](data:image/png;base64,...)

# %% [markdown]
# ###PERIODO

# %% [markdown]
# ![lab 1 img4.png](data:image/png;base64,...)

# %% [markdown]
# ###Gráfica T(s) vs Dmedio (s)

# %% [markdown]
# ![lab 1 img5.png](data:image/png;base64,...)

# %% [markdown]
# ###PERIODO DE OSCILACIÓN:

# %% [markdown]
# ![lab 1 img6.png](data:image/png;base64,...)

# %% [markdown]
# ###Discusión:
# >Notamos cómo entre más grande es el diámetro del anillo, el periodo de tiempo que
# va a tardar en realizar una oscilación va a ser mayor, esto debido a que su masa al
# ser mayor, le costaba un poco más de tiempo pasar el punto donde este se tomaba,
# algo similar ocurre con el diámetro y su masa de cada anillo, a causa de que, estos
# datos los podemos determinar como directamente proporcionales, ya que el anillo
# que tenía la mayor longitud de diámetro a su misma vez era el más pesado.
#
# >Por otro lado podemos observar como el error experimental al ser de un 81%
# aproximadamente, no fue el mejor debido a que se realizaron mediciones con
# distintos instrumentos que hicieron que los datos, aunque no variarán de forma
# abrupta, si disminuyeran la precisión del experimento, en vista de esto, se vieron
# valores muy cercanos para diferentes anillos pero todos siendo relevantes para el
# desarrollo de la práctica.
#
# ###Conclusión:
# >Finalmente, después de haber desarrollado todos los procesos pertinentes para
# finalizar este laboratorio, se pudieron concluir distintos enunciados. Primeramente,
# se debe resaltar que la hipótesis planteada en un principio, en la introducción, fue
# totalmente acertada; según se planteaba, decía: entre más grande sea su diámetro
# (diámetro del anillo), más lento será su periodo de oscilación.
#
# >Con base en las
# tablas podemos reafirmar esto, es una característica importante. Por otro lado, en
# este caso se observa una relación directamente proporcional en la masa y el
# diámetro (interno y externo) del anillo, aumenta (x) conforme aumenta (y).
# Por otro lado, se tendrá en cuenta para un próximo experimento el proceso de tomar
# medidas, en este caso del diámetro. Se deberán tomar todas las medidas con el
# mismo instrumento de medición, así se reducirá el margen de error. La organización
# será un ámbito muy relevante en el cual se debe mejorar por parte del aula al
# momento de brindar los datos obtenidos en el experimento hecho a priori.
#
#
# >Básicamente, el experimento se llevó a cabo, donde fueron correctas las hipótesis,
# donde se aprendieron distintos conceptos nuevos, se aprendieron nuevas lecciones
# tanto académicas, como sociales que ayudarán a brindar cada vez un mejor
# proceso experimental.
